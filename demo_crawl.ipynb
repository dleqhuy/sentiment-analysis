# %% [markdown]
# <a href="https://colab.research.google.com/github/dleqhuy/Sentiment_Analysis/blob/main/demo_crawl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt install chromium-chromedriver
# !apt install -qq enchant

# !git clone https://github.com/dleqhuy/Sentiment_Analysis
# !pip install -r /content/Sentiment_Analysis/requirements.txt

# %%
import sys
sys.path.append('/content/Sentiment_Analysis')
# %load_ext autoreload
# %autoreload 2
from modules import crawler
from modules import utils

# %%
my_pham = {'chăm sóc da':
           {'sửa rửa mặt','lotion','kem duõng ẩm',
            'mặt nạ','toner','nước hoa hồng',
            'bông tẩy trang','nước tẩy trang','mụn',
            'trị mụn','kem trị mụn','thâm',
            'trị thâm','kem trị thâm','bỏng',
            'phỏng','sẹo','kem trị sẹo','vitamic c',
            'cấp ẩm','xịt khoáng','lột mụn','son dưỡng',}}

# %%
for pr in my_pham['chăm sóc da']:

  URLsSearch = crawler.getURLsSearch(pr)
  #crawl từ trang 1 đến 2
  product_info = (crawler.getProductURLs(URLsSearch,[0, 1], "shopee-search-item-result__item"))
  #tạo DataFrame
  product_info = pd.DataFrame(product_info,columns=['product_urls','sell_number'])
  #ghi ra csv
  product_info.to_csv(f"/content/drive/MyDrive/shopee/product_info/{pr}.csv",,index=False)

# %%
infos = utils.readCSVfromfolder('/content/drive/MyDrive/shopee/product_info/')
# Out:
#                                           product_urls  sell_number
# 0    https://shopee.vn/B%E1%BB%99-kem-gi%E1%BA%A3m-...      38000.0
# 1    https://shopee.vn/B%E1%BB%99-s%E1%BA%A3n-ph%E1...      33000.0
# 2    https://shopee.vn/Serum-gi%E1%BA%A3m-m%E1%BB%A...     485000.0
# 3    https://shopee.vn/Kem-D%C6%B0%E1%BB%A1ng-Gi%C3...       5000.0
# 4    https://shopee.vn/-M%C3%A3-COSDHCBD1-gi%E1%BA%...      23000.0
# ..                                                 ...          ...
# 927  https://shopee.vn/DERMA-FORTE-Gel-H%E1%BB%97-T...         19.0
# 928  https://shopee.vn/X%C3%A0-ph%C3%B2ng-c%C3%A1m-...          1.0
# 929  https://shopee.vn/Kem-d%C6%B0%E1%BB%A1ng-tr%E1...     107000.0
# 930  https://shopee.vn/-SALE-CAM-K%E1%BA%BET-100-CH...     147000.0
# 931  https://shopee.vn/B%E1%BB%99-s%E1%BA%A3n-ph%E1...      73000.0
#
# [932 rows x 2 columns]

# %%
for idx, product_url in enumerate(infos['product_urls']): # đi qua từng URL của sản phẩm
    new_reviews = crawler.getProductReviewsAPI(product_url) # lấy tất cả review của sản phẩm này
    crawler.writeToCsv(f"/content/drive/MyDrive/shopee/product_reviews/product_{idx}.csv", new_reviews) # ghi mọi review của sản phẩm này ra file

# %%
reviews = utils.readCSVfromfolder('/content/drive/MyDrive/shopee/product_reviews/')
reviews
# Out:
#                                                  comment  rating
# 0      Tuýp rửa mặt nhỏ hơn bthan nghĩ. Bị dò hay sao...       5
# 1      Sản phẩm date mới, đầy đủ, chính hãng, giao hà...       5
# 2      nhận hàng mình rất hài lòng hàng giao nhanh gi...       5
# 3      Chưa sủa dụng nên không biết có hiệu quả hay k...       5
# 4      Mới dùng loại này lần đầu nên ko biết hiệu quả...       5
# ...                                                  ...     ...
# 14127  Không thấy có tác dụng mấy. Khá to và dùng đượ...       4
# 14128  Chất lượng sp tuyệt vời\nĐóng gói sản phẩm rất...       5
# 14129  Mua về cho vui thôi k bắn dc đâu mng =)))) bỏ ...       5
# 14130                                             Ok nhá       5
# 14131                           Đặt bị cứ lăn ko đánh đc       1
#
# [14132 rows x 2 columns]
